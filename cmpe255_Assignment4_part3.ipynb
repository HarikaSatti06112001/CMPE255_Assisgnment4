# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikaSatti06112001/CMPE255_Assisgnment4/blob/main/cmpe255_Assignment4_part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/coffee-listings-from-all-walmart-stores.csv")
df
# Out:
#                                                   title  \
# 0       folgers classic roast ground coffee, 40.3-ounce
# 1     café bustelo, espresso style dark roast ground...
# 2     folgers classic roast ground coffee, medium ro...
# 3     maxwell house original roast ground coffee, 42...
# 4     great value classic roast medium ground coffee...
# ...                                                 ...
# 1395  xhao reusable capsules easy to clean easy to u...
# 1396  cafe yaucono espresso dark roast ground coffee...
# 1397  starbucks dark roast coffee with 2x caffeine, ...
# 1398  starbucks holiday blend, medium roast k-cup co...
# 1399  super coffee vanilla latte iced coffee bottle,...
#
#                      coffee_type  rating  reviews  \
# 0                  classic roast     3.8       93
# 1            espresso,dark roast     4.7      914
# 2     medium roast,classic roast     4.4      740
# 3                            NaN     4.8     1321
# ...

# %%
# %pip install bamboolib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bamboolib as bam
bam
# Out:
# BamboolibModuleWindow(children=(Window(children=(VBox(children=(VBox(children=(Button(description='Read CSV fi…

# %%
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head(10)
# Out:
#                                                title  \
# 0    folgers classic roast ground coffee, 40.3-ounce
# 1  café bustelo, espresso style dark roast ground...
# 2  folgers classic roast ground coffee, medium ro...
# 3  maxwell house original roast ground coffee, 42...
# 4  great value classic roast medium ground coffee...
# 5  great value classic roast medium ground coffee...
# 6  caf bustelo, espresso style dark roast ground ...
# 7  xhao reusable capsules easy to clean easy to u...
# 8  black rifle coffee tactisquatch, dark roast, g...
# 9  black rifle coffee just black whole bean coffe...
#
#                        coffee_type  rating  reviews       seller_name  \
# 0                    classic roast     3.8       93       walmart.com
# 1              espresso,dark roast     4.7      914       walmart.com
# 2       medium roast,classic roast     4.4      740       walmart.com
# 3                              NaN     4.8     1321       walmart.com
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of                                                   title  \
# 0       folgers classic roast ground coffee, 40.3-ounce
# 1     café bustelo, espresso style dark roast ground...
# 2     folgers classic roast ground coffee, medium ro...
# 3     maxwell house original roast ground coffee, 42...
# 4     great value classic roast medium ground coffee...
# ...                                                 ...
# 1395  xhao reusable capsules easy to clean easy to u...
# 1396  cafe yaucono espresso dark roast ground coffee...
# 1397  starbucks dark roast coffee with 2x caffeine, ...
# 1398  starbucks holiday blend, medium roast k-cup co...
# 1399  super coffee vanilla latte iced coffee bottle,...
#
#                      coffee_type  rating  reviews  \
# 0                  classic roast     3.8       93
# 1            espresso,dark roast     4.7      914
# 2     medium roast,classic roast     4.4      740
# 3                            NaN     4.8     1321
# ...

# %%
df.columns
# Out:
# Index(['title', 'coffee_type', 'rating', 'reviews', 'seller_name', 'thumbnail',
#        'price', 'weight', 'weight_formatted_to_gramms'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       1400 non-null   object
#  1   coffee_type                 1121 non-null   object
#  2   rating                      1400 non-null   float64
#  3   reviews                     1400 non-null   int64
#  4   seller_name                 1400 non-null   object
#  5   thumbnail                   1400 non-null   object
#  6   price                       1400 non-null   float64
#  7   weight                      1400 non-null   object
#  8   weight_formatted_to_gramms  1400 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 98.6+ KB

# %%
sns.pairplot(df)

# %%
from collections import Counter
Counter(df['rating'])
# Out:
# Counter({3.8: 42,
#          4.7: 224,
#          4.4: 87,
#          4.8: 223,
#          4.2: 20,
#          0.0: 168,
#          3.0: 3,
#          3.7: 8,
#          4.9: 85,
#          4.6: 198,
#          4.3: 52,
#          3.5: 40,
#          4.5: 141,
#          4.1: 18,
#          3.4: 4,
#          4.0: 19,
#          5.0: 45,
#          3.1: 1,
#          3.2: 2,
#          3.9: 7,
#          3.3: 5,
#          2.1: 1,
#          2.9: 2,
#          3.6: 2,
#          2.5: 1,
#          1.0: 1,
#          1.8: 1})

# %%
sns.countplot(x='rating', data=df)

# %%
sns.boxplot('rating', 'reviews', data = df)

# %%
sns.boxplot('rating', 'price', data = df)

# %%
sns.boxplot('rating', 'coffee_type', data = df)

# %%
sns.boxplot('rating', 'weight', data = df)

# %%
df.describe()
# Out:
#             rating       reviews        price  weight_formatted_to_gramms
# count  1400.000000   1400.000000  1400.000000                 1400.000000
# mean      3.982643    440.853571    14.041343                  621.391786
# std       1.518037    879.351997    10.257832                  369.564693
# min       0.000000      0.000000     0.000000                    0.000000
# 25%       4.300000     16.000000     7.950000                  340.200000
# 50%       4.600000    136.000000    12.735000                  567.000000
# 75%       4.800000    604.500000    16.990000                  850.500000
# max       5.000000  15148.000000    77.090000                 2835.000000

# %%
df.columns
# Out:
# Index(['title', 'coffee_type', 'rating', 'reviews', 'seller_name', 'thumbnail',
#        'price', 'weight', 'weight_formatted_to_gramms'],
#       dtype='object')

# %%
df['reviews'].unique()
# Out:
# array([   93,   914,   740,  1321,  1598,   263,     0,     6,    10,
#           20,    11,     5,     3,  1512,   667,   870,   495,   630,
#            8,   673,  1226,   166,   112,   772,    13,   536,   279,
#           64,   527,   604,  1060,  2444,   349,   266,   507,  1537,
#          869,   901,    96,   511,   255,   682, 15148,   123,   613,
#          786,  1237,    97,   389,   774,   554,   388,   292,   524,
#          360,   568,   450,   395,   143,   190,   320,   758,  1309,
#          196,   345,   614,   151,   532,   585,   547,   420,   461,
#          131,   107,   624,   184,   314,   615,   730,  2738,  1295,
#          150,   428,   949,   269,   427,  1707,   528,  3585,   336,
#          271,  4165,   253,   126,   149,   283,   472,    67,   932,
#          179,   955,  3335,  1024,   304,    55,   851,  1924,   379,
#         1872,   442,   419,   421,   175,    45,    83,   130,   312,
# ...

# %%
Counter(df['reviews'])
# Out:
# Counter({93: 32,
#          914: 32,
#          740: 27,
#          1321: 32,
#          1598: 1,
#          263: 1,
#          0: 168,
#          6: 11,
#          10: 6,
#          20: 36,
#          11: 28,
#          5: 14,
#          3: 10,
#          1512: 1,
#          667: 1,
#          870: 27,
#          495: 32,
#          630: 8,
#          8: 36,
#          673: 1,
#          1226: 7,
#          166: 3,
#          112: 3,
#          772: 1,
#          13: 5,
#          536: 1,
#          279: 2,
#          64: 30,
#          527: 7,
#          604: 1,
#          1060: 2,
#          2444: 3,
#          349: 2,
#          266: 3,
#          507: 2,
#          1537: 7,
#          869: 1,
#          901: 1,
#          96: 2,
#          511: 1,
#          255: 3,
#          682: 2,
#          15148: 1,
#          123: 2,
#          613: 2,
#          786: 1,
#          1237: 1,
#          97: 3,
#          389: 1,
#          774: 1,
#          554: 1,
#          388: 1,
# ...

# %%
x = df.iloc[:,:11]
y = df['reviews']

# %%
x.head(10)
# Out:
#                                                title  \
# 0    folgers classic roast ground coffee, 40.3-ounce
# 1  café bustelo, espresso style dark roast ground...
# 2  folgers classic roast ground coffee, medium ro...
# 3  maxwell house original roast ground coffee, 42...
# 4  great value classic roast medium ground coffee...
# 5  great value classic roast medium ground coffee...
# 6  caf bustelo, espresso style dark roast ground ...
# 7  xhao reusable capsules easy to clean easy to u...
# 8  black rifle coffee tactisquatch, dark roast, g...
# 9  black rifle coffee just black whole bean coffe...
#
#                        coffee_type  rating  reviews       seller_name  \
# 0                    classic roast     3.8       93       walmart.com
# 1              espresso,dark roast     4.7      914       walmart.com
# 2       medium roast,classic roast     4.4      740       walmart.com
# 3                              NaN     4.8     1321       walmart.com
# ...

# %%
print(x.dtypes)
# Out:
# title                          object
# coffee_type                    object
# rating                        float64
# reviews                         int64
# seller_name                    object
# thumbnail                      object
# price                         float64
# weight                         object
# weight_formatted_to_gramms    float64
# dtype: object

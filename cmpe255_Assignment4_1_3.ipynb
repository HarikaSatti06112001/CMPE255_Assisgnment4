# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikaSatti06112001/CMPE255_Assisgnment4/blob/main/cmpe255_Assignment4_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/IRIS.csv')
df.dropna(axis=1,inplace=True)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df['petal_width'] = df['petal_width']/df['petal_width'].max()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4         0.08  Iris-setosa
# 1           4.9          3.0           1.4         0.08  Iris-setosa
# 2           4.7          3.2           1.3         0.08  Iris-setosa
# 3           4.6          3.1           1.5         0.08  Iris-setosa
# 4           5.0          3.6           1.4         0.08  Iris-setosa

# %%
df['petal_length'] = (df['petal_length'] - df['petal_length'].min())/(df['petal_length'].max() - df['petal_length'].min())

# %%
df['sepal_length'] = (df['sepal_length']-df['sepal_length'].mean())/df['sepal_length'].std()

# %%
df['sepal_length'].min()
# Out:
# -1.8637802962695176

# %%
df['sepal_length'].max()
# Out:
# 2.4836985805578657

# %%
import numpy as np

df['sepal_width'] = df['sepal_width'].apply(lambda x: np.log(x) if x != 0 else 0)

# %%
vmax = 10000
vmin = 10

df['petal_length'] = df['petal_length'].apply(lambda x: vmax if x > vmax else vmin if x < vmin else x)

# %%
import pandas as pd
df = pd.read_csv('/content/IRIS.csv')
df.dropna(axis=1,inplace=True)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
import numpy as np
from sklearn.preprocessing import MaxAbsScaler

X = np.array(df['petal_length']).reshape(-1,1)
scaler = MaxAbsScaler()

# %%
scaler.fit(X)
X_scaled = scaler.transform(X)
df['sepal_width	'] = X_scaled.reshape(1,-1)[0]
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_width\t
# 0       0.202899
# 1       0.202899
# 2       0.188406
# 3       0.217391
# 4       0.202899

# %%
scaler.inverse_transform(X_scaled)
# Out:
# array([[1.4],
#        [1.4],
#        [1.3],
#        [1.5],
#        [1.4],
#        [1.7],
#        [1.4],
#        [1.5],
#        [1.4],
#        [1.5],
#        [1.5],
#        [1.6],
#        [1.4],
#        [1.1],
#        [1.2],
#        [1.5],
#        [1.3],
#        [1.4],
#        [1.7],
#        [1.5],
#        [1.7],
#        [1.5],
#        [1. ],
#        [1.7],
#        [1.9],
#        [1.6],
#        [1.6],
#        [1.5],
#        [1.4],
#        [1.6],
#        [1.6],
#        [1.5],
#        [1.5],
#        [1.4],
#        [1.5],
#        [1.2],
#        [1.3],
#        [1.5],
#        [1.3],
#        [1.5],
#        [1.3],
#        [1.3],
#        [1.3],
#        [1.6],
#        [1.9],
#        [1.4],
#        [1.6],
#        [1.4],
#        [1.5],
#        [1.4],
#        [4.7],
#        [4.5],
#        [4.9],
#        [4. ],
#        [4.6],
#        [4.5],
#        [4.7],
#        [3.3],
#        [4.6],
#        [3.9],
#        [3.5],
#        [4.2],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
X = np.array(df['petal_length']).reshape(-1,1)
scaler = MinMaxScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
df['min max'] = X_scaled.reshape(1,-1)[0]
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_width\t   min max
# 0       0.202899  0.067797
# 1       0.202899  0.067797
# 2       0.188406  0.050847
# 3       0.217391  0.084746
# 4       0.202899  0.067797

# %%
from sklearn.preprocessing import StandardScaler

X = np.array(df['petal_length']).reshape(-1,1)
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
df['z score'] = X_scaled.reshape(1,-1)[0]
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_width\t   min max   z score
# 0       0.202899  0.067797 -1.341272
# 1       0.202899  0.067797 -1.341272
# 2       0.188406  0.050847 -1.398138
# 3       0.217391  0.084746 -1.284407
# 4       0.202899  0.067797 -1.341272
